# %% [markdown]
# # EDA Part -1 :
#
# This notebook contains basic exploration around the `Mercari Dataset`.

# %%
# import essentials
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the dataset:

# %%
# URL where data is dumped

gcp_url = 'https://storage.googleapis.com/price-alchemy/Mercari%20price%20suggestion%20challenge/train.tsv'

df = pd.read_csv(gcp_url, sep='\t', header=0)

# %% [markdown]
# What does our dataset look like?

# %%
df.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
df.shape
# Out:
# (1482535, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   category_name      1476208 non-null  object
#  4   brand_name         849853 non-null   object
#  5   price              1482535 non-null  float64
#  6   shipping           1482535 non-null  int64
#  7   item_description   1482531 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 90.5+ MB

# %%
# Randomly selecting 10% of categories and brands to hold out with a fixed random state
import random

# Set the random seed
random.seed(42)

# Select categories
unique_categories = df['category_name'].unique()
categories_to_hold_out = random.sample(list(unique_categories), int(0.1 * len(unique_categories)))

# Select brands
unique_brands = df['brand_name'].unique()
brands_to_hold_out = random.sample(list(unique_brands), int(0.1 * len(unique_brands)))

# %%
len(categories_to_hold_out)
# Out:
# 128

# %%
len(brands_to_hold_out)
# Out:
# 481

# %%
# Filter records to be held out
df_holdout = df[(df['category_name'].isin(categories_to_hold_out)) | (df['brand_name'].isin(brands_to_hold_out))]

df_holdout
# Out:
#          train_id                                  name  item_condition_id  \
# 6               6    Acacia pacific tides santorini top                  3
# 7               7  Girls cheer and tumbling bundle of 7                  3
# 14             14    HOLD for Dogs2016 Minnetonka boots                  3
# 18             18   Too Faced Limited "Merry Macaroons"                  1
# 24             24            Black and Red Baseball Tee                  2
# ...           ...                                   ...                ...
# 1482487   1482487                         Blazer bundle                  2
# 1482505   1482505                NorthFace rain jacket!                  3
# 1482506   1482506            KitchenAid 4.5 quart mixer                  1
# 1482512   1482512                             Lululemon                  2
# 1482531   1482531         Little mermaid handmade dress                  2
#
#                                    category_name       brand_name  price  \
# 6                       Women/Swimwear/Two-Piece  Acacia Swimwear   64.0
# 7                Sports & Outdoors/Apparel/Girls            Soffe    6.0
# 14                             Women/Shoes/Boots    UGG Australia   43.0
# 18                 Beauty/Makeup/Makeup Palettes        Too Faced   25.0
# 24                 Women/Tops & Blouses/T-Shirts       FOREVER 21   10.0
# ...                                          ...              ...    ...
# 1482487             Women/Suits & Blazers/Blazer       FOREVER 21   31.0
# 1482505           Women/Coats & Jackets/Raincoat   The North Face   34.0
# 1482506  Home/Home Appliances/Kitchen Appliances       KitchenAid  165.0
# 1482512     Women/Athletic Apparel/Shirts & Tops        Lululemon   34.0
# 1482531                 Kids/Girls 2T-5T/Dresses           Disney   14.0
#
#          shipping                                   item_description
# 6               0  Size small but straps slightly shortened to fi...
# 7               1  You get three pairs of Sophie cheer shorts siz...
# 14              0  Authentic. Suede fringe boots. Great condition...
# 18              1  This AUTHENTIC pallete by Too Faced is brand n...
# 24              0  lanascloset ~~~ description: never worn! ✨ i d...
# ...           ...                                                ...
# 1482487         0  White blazer- forever 21 size medium, fits sma...
# 1482505         0  great condition! a few signs of wear on the in...
# 1482506         0  Brand new sealed in box kitchen aid kitchenaid...
# 1482512         0                               NWOT - Blue - size 8
# 1482531         0   Little mermaid handmade dress never worn size 2t
#
# [210129 rows x 8 columns]

# %%
# Remove held-out records from the original DataFrame
df_train = df[~df.index.isin(df_holdout.index)]

df_train
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1       Razer BlackWidow Chroma Keyboard                  3
# 2               2                         AVA-VIV Blouse                  1
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# ...           ...                                    ...                ...
# 1482529   1482529                          Men's UA [rm]                  2
# 1482530   1482530             Free People Inspired Dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                              category_name    brand_name  \
# 0                                        Men/Tops/T-shirts           NaN
# 1        Electronics/Computers & Tablets/Components & P...         Razer
# 2                              Women/Tops & Blouses/Blouse        Target
# 3                       Home/Home Décor/Home Décor Accents           NaN
# 4                                  Women/Jewelry/Necklaces           NaN
# ...                                                    ...           ...
# 1482529                 Men/Athletic Apparel/Shirts & Tops  Under Armour
# 1482530                             Women/Dresses/Mid-Calf   Free People
# 1482532     Sports & Outdoors/Exercise/Fitness accessories           NaN
# 1482533                 Home/Home Décor/Home Décor Accents           NaN
# 1482534                  Women/Women's Accessories/Wallets           NaN
#
#          price  shipping                                   item_description
# 0         10.0         1                                 No description yet
# 1         52.0         0  This keyboard is in great condition and works ...
# 2         10.0         1  Adorable top with a hint of lace and a key hol...
# 3         35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4         44.0         0          Complete with certificate of authenticity
# ...        ...       ...                                                ...
# 1482529   34.0         0  [rm] for the set both in perfect condition no ...
# 1482530   20.0         1  Lace, says size small but fits medium perfectl...
# 1482532   12.0         0          Used once or twice, still in great shape.
# 1482533   45.0         1  There is 2 of each one that you see! So 2 red ...
# 1482534   22.0         0  New with tag, red with sparkle. Firm price, no...
#
# [1272406 rows x 8 columns]

# %%
# Randomly sample 500K records from df_train
holdout_data = df_train.sample(n=300000, random_state=42)

holdout_data
# Out:
#          train_id                                    name  item_condition_id  \
# 58022       58022               Vs temptation perfume new                  1
# 1472596   1472596  Kylie Cosmetics Liquid Lipstick Koko K                  2
# 173387     173387                     TC LULAROE LEGGINGS                  2
# 612079     612079                           Volcom Shorts                  2
# 149163     149163                 Enfamil Formula Coupons                  1
# ...           ...                                     ...                ...
# 956296     956296     Vintage Folding Fan Necklace & Ring                  3
# 200239     200239                           Toddler socks                  3
# 496175     496175                              Tan Shorts                  2
# 97648       97648                       Unlocked iPhone 6                  3
# 161867     161867                      Pug stuffed animal                  3
#
#                                              category_name         brand_name  \
# 58022                               Beauty/Fragrance/Women  Victoria's Secret
# 1472596                                 Beauty/Makeup/Lips    Kylie Cosmetics
# 173387                                Women/Jeans/Leggings            LuLaRoe
# 612079                       Women/Athletic Apparel/Shorts             Volcom
# 149163                         Kids/Feeding/Bottle-Feeding            Enfamil
# ...                                                    ...                ...
# 956296                             Women/Jewelry/Necklaces                NaN
# 200239                               Kids/Boys 2T-5T/Other                NaN
# 496175                       Women/Athletic Apparel/Shorts             Merona
# 97648    Electronics/Cell Phones & Accessories/Cell Pho...              Apple
# 161867                   Kids/Toys/Stuffed Animals & Plush                NaN
#
#          price  shipping                                   item_description
# 58022     14.0         0                    Vs temptation perfume 8.4oz new
# 1472596   16.0         0            Not used No box No lip Liner Price Firm
# 173387    12.0         0  Brand new never worn! Please check out my othe...
# 612079    10.0         0               Size 00 never worn, bought at pacsun
# 149163     7.0         1  [rm] value for formula 1- expires February 28 ...
# ...        ...       ...                                                ...
# 956296     9.0         0  Vintage Chinese Folding fan necklace plus free...
# 200239    10.0         0          These are toddler socks in a ok condition
# 496175    13.0         0        Beige, tan, khaki shorts. Comfy. Worn once.
# 97648    250.0         1  White unlocked iPhone 6. Great condition. No c...
# 161867    11.0         0  He's a light cream Very soft Great to cuddle w...
#
# [300000 rows x 8 columns]

# %%
# Remove sampled records from df_train
df_train = df_train[~df_train.index.isin(holdout_data.index)]
df_train
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1       Razer BlackWidow Chroma Keyboard                  3
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# 8               8                  Girls Nike Pro shorts                  3
# ...           ...                                    ...                ...
# 1482527   1482527  Blk/white ribbed mock neck bodysuit M                  1
# 1482528   1482528    Victoria's Secret Tankini Sz. Large                  2
# 1482529   1482529                          Men's UA [rm]                  2
# 1482530   1482530             Free People Inspired Dress                  2
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                              category_name         brand_name  \
# 0                                        Men/Tops/T-shirts                NaN
# 1        Electronics/Computers & Tablets/Components & P...              Razer
# 3                       Home/Home Décor/Home Décor Accents                NaN
# 4                                  Women/Jewelry/Necklaces                NaN
# 8                          Sports & Outdoors/Apparel/Girls               Nike
# ...                                                    ...                ...
# 1482527                        Women/Tops & Blouses/Blouse                NaN
# 1482528                 Women/Athletic Apparel/Sports Bras  Victoria's Secret
# 1482529                 Men/Athletic Apparel/Shirts & Tops       Under Armour
# 1482530                             Women/Dresses/Mid-Calf        Free People
# 1482534                  Women/Women's Accessories/Wallets                NaN
#
#          price  shipping                                   item_description
# 0         10.0         1                                 No description yet
# 1         52.0         0  This keyboard is in great condition and works ...
# 3         35.0         1  New with tags. Leather horses. Retail for [rm]...
# 4         44.0         0          Complete with certificate of authenticity
# 8         19.0         0   Girls Size small Plus green. Three shorts total.
# ...        ...       ...                                                ...
# 1482527   10.0         1  Brand new black and white ribbed mock neck bod...
# 1482528   18.0         1  Purple and Paisley Victoria's Secret Tankini S...
# 1482529   34.0         0  [rm] for the set both in perfect condition no ...
# 1482530   20.0         1  Lace, says size small but fits medium perfectl...
# 1482534   22.0         0  New with tag, red with sparkle. Firm price, no...
#
# [972406 rows x 8 columns]

# %%
# Add sampled records to df_holdout
df_holdout = pd.concat([df_holdout, holdout_data], ignore_index=True)
df_holdout
# Out:
#         train_id                                  name  item_condition_id  \
# 0              6    Acacia pacific tides santorini top                  3
# 1              7  Girls cheer and tumbling bundle of 7                  3
# 2             14    HOLD for Dogs2016 Minnetonka boots                  3
# 3             18   Too Faced Limited "Merry Macaroons"                  1
# 4             24            Black and Red Baseball Tee                  2
# ...          ...                                   ...                ...
# 510124    956296   Vintage Folding Fan Necklace & Ring                  3
# 510125    200239                         Toddler socks                  3
# 510126    496175                            Tan Shorts                  2
# 510127     97648                     Unlocked iPhone 6                  3
# 510128    161867                    Pug stuffed animal                  3
#
#                                             category_name       brand_name  \
# 0                                Women/Swimwear/Two-Piece  Acacia Swimwear
# 1                         Sports & Outdoors/Apparel/Girls            Soffe
# 2                                       Women/Shoes/Boots    UGG Australia
# 3                           Beauty/Makeup/Makeup Palettes        Too Faced
# 4                           Women/Tops & Blouses/T-Shirts       FOREVER 21
# ...                                                   ...              ...
# 510124                            Women/Jewelry/Necklaces              NaN
# 510125                              Kids/Boys 2T-5T/Other              NaN
# 510126                      Women/Athletic Apparel/Shorts           Merona
# 510127  Electronics/Cell Phones & Accessories/Cell Pho...            Apple
# 510128                  Kids/Toys/Stuffed Animals & Plush              NaN
#
#         price  shipping                                   item_description
# 0        64.0         0  Size small but straps slightly shortened to fi...
# 1         6.0         1  You get three pairs of Sophie cheer shorts siz...
# 2        43.0         0  Authentic. Suede fringe boots. Great condition...
# 3        25.0         1  This AUTHENTIC pallete by Too Faced is brand n...
# 4        10.0         0  lanascloset ~~~ description: never worn! ✨ i d...
# ...       ...       ...                                                ...
# 510124    9.0         0  Vintage Chinese Folding fan necklace plus free...
# 510125   10.0         0          These are toddler socks in a ok condition
# 510126   13.0         0        Beige, tan, khaki shorts. Comfy. Worn once.
# 510127  250.0         1  White unlocked iPhone 6. Great condition. No c...
# 510128   11.0         0  He's a light cream Very soft Great to cuddle w...
#
# [510129 rows x 8 columns]

# %% [markdown]
# **Final training dataset**

# %%
# Shuffle the rows
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Generate random timestamps for created_at between 2022-01-01 and 2024-03-05
start_date = pd.to_datetime('2022-01-01')
end_date = pd.to_datetime('2024-03-05')

df_train['created_at'] = np.random.choice(pd.date_range(start=start_date, end=end_date, freq='T'), len(df_train))
df_train['last_updated_at'] = df_train['created_at']

# Sort the DataFrame based on created_at timestamp in ascending order
df_train = df_train.sort_values(by='created_at').reset_index(drop=True)

df_train
# Out:
#         train_id                               name  item_condition_id  \
# 0         793697                         Plaid Vest                  2
# 1         402094                    Women's Sperrys                  3
# 2         522439                 Grey sweater dress                  1
# 3         214455  Tory Burch 'Perry' Leather Wallet                  3
# 4         902755       Fujifilm Rainbow Instax Film                  1
# ...          ...                                ...                ...
# 972401    700766           LF Floral Hooded Flannel                  3
# 972402   1277823       Rae Dunn FAMILY & FEAST Mugs                  1
# 972403   1446057             ‼️LAST CHANCE TO GET‼️                  3
# 972404    222392                 ⭐️OPI - Race Red⭐️                  1
# 972405    151885                 Boho Cardigan Vest                  2
#
#                                             category_name       brand_name  \
# 0                              Women/Coats & Jackets/Vest         Old Navy
# 1                          Women/Shoes/Loafers & Slip-Ons          Sperrys
# 2                                     Women/Dresses/Other     Fashion Nova
# 3                       Women/Women's Accessories/Wallets       Tory Burch
# 4       Electronics/Cameras & Photography/Film Photogr...             Fuji
# ...                                                   ...              ...
# 972401                              Women/Sweaters/Hooded               LF
# 972402     Home/Kitchen & Dining/Coffee & Tea Accessories              NaN
# 972403                     Women/Dresses/Above Knee, Mini  Brandy Melville
# 972404                                Beauty/Makeup/Nails              NaN
# 972405                            Women/Sweaters/Cardigan              NaN
#
#         price  shipping                                   item_description  \
# 0        11.0         1  Green and blue. Very thick and soft! Perfect f...
# 1        21.0         0                                                EUC
# 2        20.0         1  This is a heather grey sweater dress from fash...
# 3        91.0         0  Tory Burch 'Perry' Leather Zip Continental Wal...
# 4        14.0         0                                 No description yet
# ...       ...       ...                                                ...
# 972401  154.0         0  LF Floral Hooded Flannel. One Size. EUC - blue...
# 972402   24.0         0  This is the exact item you will receive. I fin...
# 972403   24.0         0      Cream and grey floral dress with low cut back
# 972404    7.0         1  ❤️Brand New • Full Size • Authentic❤️ ✨In this...
# 972405   12.0         0  This cardigan is beautiful and can make any ou...
#
#                 created_at     last_updated_at
# 0      2022-01-01 00:00:00 2022-01-01 00:00:00
# 1      2022-01-01 00:01:00 2022-01-01 00:01:00
# 2      2022-01-01 00:01:00 2022-01-01 00:01:00
# 3      2022-01-01 00:03:00 2022-01-01 00:03:00
# 4      2022-01-01 00:05:00 2022-01-01 00:05:00
# ...                    ...                 ...
# 972401 2024-03-04 23:53:00 2024-03-04 23:53:00
# 972402 2024-03-04 23:57:00 2024-03-04 23:57:00
# 972403 2024-03-04 23:57:00 2024-03-04 23:57:00
# 972404 2024-03-04 23:58:00 2024-03-04 23:58:00
# 972405 2024-03-04 23:58:00 2024-03-04 23:58:00
#
# [972406 rows x 10 columns]

# %%
#!pip install google-cloud-storage

# %%
from google.cloud import storage

path_to_private_key = '/home/bishal/mlops/project/Price_Alchemy/ringed-reserve-416823-b54bbb8174c1.json'
client = storage.Client.from_service_account_json(json_credentials_path=path_to_private_key)

# %%
#df_train.to_csv("df_train.csv")

# The bucket on GCS in which to write the CSV file
bucket = client.bucket('price_alchemy')
# The name assigned to the CSV file on GCS
blob = bucket.blob('Data/data.csv')
blob.upload_from_string(df_train.to_csv(index=False), 'text/csv')

# %% [markdown]
# **Final holdout dataset**

# %%
# Shuffle the rows
df_holdout = df_holdout.sample(frac=1, random_state=42).reset_index(drop=True)
df_holdout.head()
# Out:
#    train_id                       name  item_condition_id  \
# 0    530625      Kate Spade Sunglasses                  2
# 1    876172          Faux piercings ⚡️                  1
# 2    919501    Women's Columbia Jacket                  2
# 3    820303        Doctor Strange #166                  3
# 4    186019  iPhone 5s waterproof case                  3
#
#                                        category_name  brand_name  price  \
# 0               Women/Women's Accessories/Sunglasses  Kate Spade   40.0
# 1                           Handmade/Jewelry/Jewelry         NaN    4.0
# 2                     Women/Athletic Apparel/Jackets    Columbia   30.0
# 3                 Vintage & Collectibles/Book/Comics         NaN   10.0
# 4  Electronics/Cell Phones & Accessories/Cases, C...         NaN   10.0
#
#    shipping                                   item_description
# 0         0  Kate Spade Cat Eye Sunglasses. Color black wit...
# 1         1  Faux Nose Rings!! •Now you can look stylish wi...
# 2         0  Women's black, medium Columbia Jacket. Excelle...
# 3         1                                 No description yet
# 4         1  Blue iPhone 5s/5c/5 case good condition. Teste...

# %%
df_train.shape
# Out:
# (972406, 10)

# %%
import csv
import math

df_train_dump = df_train.copy()

batch_size = 200000
total_rows = len(df_train_dump)

# The bucket on GCS in which to write the CSV files
bucket = client.bucket('price_alchemy')

# Calculate the number of batches
num_batches = math.ceil(total_rows / batch_size)
num_batches
# Out:
# 5

# %%
# Add a new column 'index_column' starting from 1
df_train_dump.insert(0, 'id', range(1, len(df_train_dump) + 1))
df_train_dump.head()
# Out:
#    id  train_id                               name  item_condition_id  \
# 0   1    793697                         Plaid Vest                  2
# 1   2    402094                    Women's Sperrys                  3
# 2   3    522439                 Grey sweater dress                  1
# 3   4    214455  Tory Burch 'Perry' Leather Wallet                  3
# 4   5    902755       Fujifilm Rainbow Instax Film                  1
#
#                                        category_name    brand_name  price  \
# 0                         Women/Coats & Jackets/Vest      Old Navy   11.0
# 1                     Women/Shoes/Loafers & Slip-Ons       Sperrys   21.0
# 2                                Women/Dresses/Other  Fashion Nova   20.0
# 3                  Women/Women's Accessories/Wallets    Tory Burch   91.0
# 4  Electronics/Cameras & Photography/Film Photogr...          Fuji   14.0
#
#    shipping                                   item_description  \
# 0         1  Green and blue. Very thick and soft! Perfect f...
# 1         0                                                EUC
# 2         1  This is a heather grey sweater dress from fash...
# 3         0  Tory Burch 'Perry' Leather Zip Continental Wal...
# 4         0                                 No description yet
#
#            created_at     last_updated_at
# 0 2022-01-01 00:00:00 2022-01-01 00:00:00
# 1 2022-01-01 00:01:00 2022-01-01 00:01:00
# 2 2022-01-01 00:01:00 2022-01-01 00:01:00
# 3 2022-01-01 00:03:00 2022-01-01 00:03:00
# 4 2022-01-01 00:05:00 2022-01-01 00:05:00

# %%
df_train_dump.tail()
# Out:
#             id  train_id                          name  item_condition_id  \
# 972401  972402    700766      LF Floral Hooded Flannel                  3
# 972402  972403   1277823  Rae Dunn FAMILY & FEAST Mugs                  1
# 972403  972404   1446057        ‼️LAST CHANCE TO GET‼️                  3
# 972404  972405    222392            ⭐️OPI - Race Red⭐️                  1
# 972405  972406    151885            Boho Cardigan Vest                  2
#
#                                          category_name       brand_name  \
# 972401                           Women/Sweaters/Hooded               LF
# 972402  Home/Kitchen & Dining/Coffee & Tea Accessories              NaN
# 972403                  Women/Dresses/Above Knee, Mini  Brandy Melville
# 972404                             Beauty/Makeup/Nails              NaN
# 972405                         Women/Sweaters/Cardigan              NaN
#
#         price  shipping                                   item_description  \
# 972401  154.0         0  LF Floral Hooded Flannel. One Size. EUC - blue...
# 972402   24.0         0  This is the exact item you will receive. I fin...
# 972403   24.0         0      Cream and grey floral dress with low cut back
# 972404    7.0         1  ❤️Brand New • Full Size • Authentic❤️ ✨In this...
# 972405   12.0         0  This cardigan is beautiful and can make any ou...
#
#                 created_at     last_updated_at
# 972401 2024-03-04 23:53:00 2024-03-04 23:53:00
# 972402 2024-03-04 23:57:00 2024-03-04 23:57:00
# 972403 2024-03-04 23:57:00 2024-03-04 23:57:00
# 972404 2024-03-04 23:58:00 2024-03-04 23:58:00
# 972405 2024-03-04 23:58:00 2024-03-04 23:58:00

# %%
for batch_num in range(1, num_batches + 1):
    # Calculate start and end indices for the current batch
    start_index = (batch_num - 1) * batch_size
    end_index = min(batch_num * batch_size, total_rows)

    # Create a DataFrame slice for the current batch
    df_batch = df_train_dump.iloc[start_index:end_index].copy()

    # The name assigned to the CSV file on GCS
    blob = bucket.blob(f'data_dump_sql/data_{batch_num}.csv')
    
    # Upload the current batch to GCS
    blob.upload_from_string(df_batch.to_csv(header=False, index=False), 'text/csv')

# %%
# df_train_dump = df_train.copy()

# # Add a new column 'index_column' starting from 1
# df_train_dump.insert(0, 'id', range(1, len(df_test) + 1))

# # The bucket on GCS in which to write the CSV file
# bucket = client.bucket('price_alchemy')
# # The name assigned to the CSV file on GCS
# blob = bucket.blob('Data/data_1.csv')
# blob.upload_from_string(df_train_dump.to_csv(header=False, index=False), 'text/csv')

# %%
# blob = bucket.blob('Data/holdout_data.csv')
# blob.upload_from_string(df_holdout.to_csv(index=False), 'text/csv')

# %%
# df_test = df_train.head()
# df_test.dtypes

# %%
# import csv

# df_test = df_train.head(100)

# # Add a new column 'index_column' starting from 1
# df_test.insert(0, 'id', range(1, len(df_test) + 1))

# # The bucket on GCS in which to write the CSV file
# bucket = client.bucket('price_alchemy')
# # The name assigned to the CSV file on GCS
# blob = bucket.blob('Data/test_data_gcp.csv')
# blob.upload_from_string(df_test.to_csv(header=False, index=False, quoting=csv.QUOTE_MINIMAL), 'text/csv')

# %% [markdown]
# **Holdout set primary key add**

# %%
# URL where data is dumped

holdout_url = 'https://storage.googleapis.com/price_alchemy/Data/holdout_data.csv'

df_holdout = pd.read_csv(holdout_url, header=0)
df_holdout
# Out:
#         train_id                                      name  item_condition_id  \
# 0         530625                     Kate Spade Sunglasses                  2
# 1         876172                         Faux piercings ⚡️                  1
# 2         919501                   Women's Columbia Jacket                  2
# 3         820303                       Doctor Strange #166                  3
# 4         186019                 iPhone 5s waterproof case                  3
# ...          ...                                       ...                ...
# 510124     55846                               Black Heels                  2
# 510125    821700  Elementary & Intermediate Algebra 6th Ed                  3
# 510126    931820            Lululemon Kung Fu Pants Size M                  3
# 510127   1036984               Acacia Heliconia Kekaha Top                  3
# 510128    860472                              Wedding sign                  1
#
#                                             category_name       brand_name  \
# 0                    Women/Women's Accessories/Sunglasses       Kate Spade
# 1                                Handmade/Jewelry/Jewelry              NaN
# 2                          Women/Athletic Apparel/Jackets         Columbia
# 3                      Vintage & Collectibles/Book/Comics              NaN
# 4       Electronics/Cell Phones & Accessories/Cases, C...              NaN
# ...                                                   ...              ...
# 510124                                  Women/Shoes/Pumps              NaN
# 510125                   Other/Books/Education & Teaching              NaN
# 510126                         Men/Athletic Apparel/Pants        Lululemon
# 510127                           Women/Swimwear/Two-Piece  Acacia Swimwear
# 510128                      Handmade/Weddings/Decorations              NaN
#
#         price  shipping                                   item_description
# 0        40.0         0  Kate Spade Cat Eye Sunglasses. Color black wit...
# 1         4.0         1  Faux Nose Rings!! •Now you can look stylish wi...
# 2        30.0         0  Women's black, medium Columbia Jacket. Excelle...
# 3        10.0         1                                 No description yet
# 4        10.0         1  Blue iPhone 5s/5c/5 case good condition. Teste...
# ...       ...       ...                                                ...
# 510124   15.0         1                                   Only worn once !
# 510125   25.0         1  College textbook with zero to minimal writing ...
# 510126   50.0         1  Size M regular Great condition! Only worn a co...
# 510127   60.0         0  Size medium , few fuzzies but perfect conditio...
# 510128   19.0         0  Perfect for the ring bearer! Can be held or hu...
#
# [510129 rows x 8 columns]

# %%
# Add a new column 'index_column' starting from 1
df_holdout.insert(0, 'id', range(1, len(df_holdout) + 1))
df_holdout.head()
# Out:
#    id  train_id                       name  item_condition_id  \
# 0   1    530625      Kate Spade Sunglasses                  2
# 1   2    876172          Faux piercings ⚡️                  1
# 2   3    919501    Women's Columbia Jacket                  2
# 3   4    820303        Doctor Strange #166                  3
# 4   5    186019  iPhone 5s waterproof case                  3
#
#                                        category_name  brand_name  price  \
# 0               Women/Women's Accessories/Sunglasses  Kate Spade   40.0
# 1                           Handmade/Jewelry/Jewelry         NaN    4.0
# 2                     Women/Athletic Apparel/Jackets    Columbia   30.0
# 3                 Vintage & Collectibles/Book/Comics         NaN   10.0
# 4  Electronics/Cell Phones & Accessories/Cases, C...         NaN   10.0
#
#    shipping                                   item_description
# 0         0  Kate Spade Cat Eye Sunglasses. Color black wit...
# 1         1  Faux Nose Rings!! •Now you can look stylish wi...
# 2         0  Women's black, medium Columbia Jacket. Excelle...
# 3         1                                 No description yet
# 4         1  Blue iPhone 5s/5c/5 case good condition. Teste...

# %%
    # The name assigned to the CSV file on GCS
    blob = bucket.blob('data_dump_sql/holdout_data.csv')
    
    # Upload the current batch to GCS
    blob.upload_from_string(df_holdout.to_csv(header=False, index=False), 'text/csv')
